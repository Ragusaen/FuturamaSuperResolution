# %% [markdown]
# # Futurama Super-resolution
# This project will aim to create higher resolution versions of early Futurama episodes. Luckily, the later seasons are in 1080p, and will therefore be used to generate ground truth and from them downscaled inputs can be generated.
#
# First, we need to generate the training data. This will be done by converting futurama episodes into a set of images. Initially, let's start by attempting to do superresolution on 64x64 -> 128x128 squares of the image. Since the old episodes are in the format 640x480, I think a resolution of 1280x960 would be good enough. So the order of increase in resolution is 4 times as many pixels.

# %%
import cv2, random, os
import torch
import torch.nn as nn
from PIL import Image
from torch.utils.data import Dataset
import numpy as np
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, Normalize, Grayscale
from tqdm.notebook import tqdm
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline
import math

low_resolution = (64, 64)
high_resolution = (128, 128)

# %% [markdown]
# ## Generating training data
# Now we need to create the data. This is done by grabbing random crops of a Futurama episode.
# ![Futurma shot crop](resources/futurama_shot.png)
#
# The cropped image is then downscaled to a lower resolution, which will be the input and then the high resolution is the target for the model.
#
# High resolution                                          | Low resolution (downscaled)
# :-------------------------------------------------------:|:----------------------------------------------------:
# ![Shot crop high resolution](resources/highres_crop.png) | ![Shot crop low resolution](resources/lowres_crop.png)

# %%
if not os.path.exists('highres'):
    os.makedirs('highres')
    
if not os.path.exists('lowres'):
    os.makedirs('lowres')

cap = cv2.VideoCapture("video/sample0.mkv")

s, frame0 = cap.read()

# Skip the first 100 frames
#cap.set(cv2.CAP_PROP_POS_FRAMES, 1000)

cw, ch = high_resolution

max_start_crop_x, max_start_crop_y = (frame0.shape[1] - cw, frame0.shape[0] - ch)

frames = cap.get(cv2.CAP_PROP_FRAME_COUNT)

i=0
for _ in tqdm(range(int(frames - 5))):
    if not cap.isOpened():
        break
    
    ret, frame = cap.read()
    
    cx = random.randint(0, max_start_crop_x)
    cy = random.randint(0, max_start_crop_y)
    
    crop = frame[cy:(cy+ch), cx:(cx+cw)]
    lowres_crop = cv2.resize(crop, low_resolution, interpolation=cv2.INTER_AREA)
    #lowres_upscaled = cv2.resize(lowres_crop, high_resolution, interpolation=cv2.INTER_CUBIC)

    cv2.imwrite('highres/sample'+str(i)+'.png', crop)
    cv2.imwrite('lowres/sample'+str(i)+'.png', lowres_crop)
    i += 1
 
cap.release()

# %% [markdown]
# ### Loading data to tensors
# Next up, we need to load this data into the tensor format for use in pytorch. We define our own dataset `ImageInputTargetDataset`, which will be able to generate input-target datapoints from images in two different folders.

# %%
def imgpath_to_tensor(img_path):
    return img_to_tensor(cv2.imread(img_path))

def img_to_tensor(img):
    return torch.from_numpy(np.asarray(img)).double().permute(2,0,1)[[2,1,0], :, :].float() / 256.0
    
class ImageInputTargetDataset(Dataset):
    def __init__(self, input_path: str, target_path: str, extension="png", prefix="", transform=None):
        self.input_path = input_path
        self.target_path = target_path
        self.transform = transform
        self.image_path_template = "{}/" + "{}".format(prefix) + "{}." + "{}".format(extension)
    
    def __len__(self):
        return len(os.listdir(self.input_path))
    
    
    
    def __getitem__(self, idx):
        
        input_img = imgpath_to_tensor(self.image_path_template.format(self.input_path, idx)) 
        target_img = imgpath_to_tensor(self.image_path_template.format(self.target_path, idx))
        
        if self.transform:
            input_img = self.transform(input_img)
            target_img = self.transform(target_img)
        
        return [input_img, target_img]

# %% [markdown]
# With this dataset format defined, we can create a `DataLoader` for it. This class can load the datapoints in batches.

# %%
batch_size = 128

dataset = ImageInputTargetDataset("lowres", "highres", prefix="sample",
                                  transform=Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)))

dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
def denorm(img_tensors):
    return img_tensors * 0.5 + 0.5

def display_imgs(imgs):
    _, axs = plt.subplots(1,len(imgs), figsize=(4*len(imgs),4))
    for i in range(len(imgs)):
        axs[i].imshow(denorm(imgs[i]).permute(1,2,0), cmap='gray')

# %%
for lr, hr in dataloader:
    display_imgs([lr[0], hr[0]])
    break

# %% [markdown]
# ## Creating the model
# The model that we will use is a simple transpose convolutional neural network.

# %%
class ConvSubPixel(nn.Module):
    """This is the first working attempt model, it uses convolutional 
    layers and then a subpixel convolution.
    """
    
    def __init__(self):
        super().__init__()
        
        # input size 3x64x64
        self.conv = nn.Sequential(
            nn.Conv2d(3, 48, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(48),
            nn.LeakyReLU(0.2, inplace=True), # 90x32x32
            
            nn.Conv2d(48, 192, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(192),
            nn.LeakyReLU(0.2, inplace=True), # 300x16x16
            
            nn.Conv2d(192, 768, kernel_size=2, stride=2, padding=0),
            nn.BatchNorm2d(768),
            nn.LeakyReLU(0.2, inplace=True), # 768x8x8
            
            nn.Conv2d(768, 3072, kernel_size=2, stride=2, padding=0),
            nn.BatchNorm2d(3072),
            nn.LeakyReLU(0.2, inplace=True), # 768x4x4
            
            nn.Conv2d(3072, 12288, kernel_size=2, stride=2, padding=0),
            nn.BatchNorm2d(12288),
            nn.LeakyReLU(0.2, inplace=True), # 12288x2x2
        )
        
        self.sub_pixel = nn.Sequential(
            nn.PixelShuffle(8), # 192x16x16
            nn.BatchNorm2d(192),
            nn.ReLU(True),
            
            nn.PixelShuffle(8), # 3x128x128
        )
        
        self.final = nn.Tanh()
        
        upscale_factor = high_resolution[0]/low_resolution[0]
        self.upsample = nn.Upsample(scale_factor=upscale_factor, mode='bilinear', align_corners=False)
        
        self.final = nn.Tanh()
        
    def forward(self, xb):
        upsampled = self.upsample(xb)
        
        out = self.conv(xb)
        out = self.sub_pixel(out)
        out = out + upsampled
        out = self.final(out)
        
        return out

# %%
def _greyscale(t):
    return torch.unsqueeze(torch.mean(t, dim=1), dim=1)

grey_transform = _greyscale

class GreyUpscale(nn.Module):
    def __init__(self):
        super().__init__()
        
        upscale_factor = high_resolution[0]/low_resolution[0]
        self.upsample = nn.Upsample(scale_factor=upscale_factor, mode='bilinear', align_corners=False)
        
        self.conv = nn.Sequential(
            nn.Conv2d(3, 48, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm2d(48),
            nn.LeakyReLU(0.2, inplace=True), # 90x32x32
            
            nn.Conv2d(48, 192, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(192),
            nn.LeakyReLU(0.2, inplace=True), # 300x16x16
            
            nn.Conv2d(192, 768, kernel_size=2, stride=2, padding=0),
            nn.BatchNorm2d(768),
            nn.LeakyReLU(0.2, inplace=True), # 768x8x8
            
            nn.Conv2d(768, 3072, kernel_size=2, stride=2, padding=0),
            nn.BatchNorm2d(3072),
            nn.LeakyReLU(0.2, inplace=True), # 768x4x4
            
            nn.Conv2d(3072, 12288, kernel_size=2, stride=2, padding=0),
            nn.BatchNorm2d(12288),
            nn.LeakyReLU(0.2, inplace=True), # 12288x2x2
        )
        
        self.sub_pixel = nn.Sequential(
            nn.PixelShuffle(8), # 192x16x16
            nn.BatchNorm2d(192),
            nn.ReLU(True),
            
            nn.PixelShuffle(8), # 3x128x128
        )
        
        self.final = nn.Tanh()

    def forward(self, xb):
        lr_grey = grey_transform(xb)
        upsample_grey = self.upsample(lr_grey)
        
        out = self.conv(lr_grey)
        out = self.sub_pixel(out)
        out = self.final(out + upsample_grey)
        
        return out

class Recolor(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.grey_conv = nn.Sequential(
            nn.Conv2d(1, 9, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(9),
            nn.LeakyReLU(0.2, inplace=True) # 10x64x64
        )
        
        self.sub_pixel = nn.PixelShuffle(2)
        
        self.final = nn.Tanh()
    
    def forward(self, g, c): # g: 1x128x128,  c: 3x64x64
        out = self.grey_conv(g)
        
        # Concat color dimensions along this
        out = torch.cat((out, c), dim=1)
        
        out = self.sub_pixel(out)
        out = self.final(out)
        return out

# %%
model = ConvSubPixel()

def upscale_image(img):
    out = model(img)
    return out

# %%
for lr, hr in dataloader:
    print(upscale_image(lr).detach()[0].shape)
    bilinear = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False)
    display_imgs([lr[0], upscale_image(lr).detach()[0], hr[0]])
    break
# Out:
# torch.Size([3, 128, 128])

# %%
train_history = []
def train(num_epochs, lr, nbatches=-1):
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fun = nn.MSELoss(reduction='sum')
    
    model.train()
    
    for epoch in range(num_epochs): 
        epoch_loss = []
        i = 0
        for lowres, highres in tqdm(dataloader):
            if nbatches != -1 and i > nbatches:
                break
            
            # Reset gradients
            opt.zero_grad()
            
            output = model(lowres)
            
            loss = loss_fun(output, highres)
            
            loss.backward()
            
            opt.step()
            
            epoch_loss.append(loss.detach().item())
            i += 1
        
        avg_loss = sum(epoch_loss) / len(epoch_loss)
        train_history.append(avg_loss)
        print('Epoch [{}/{}], loss: {:.4f}'.format(epoch+1, num_epochs, avg_loss))
    if len(train_history) > 1:
        plt.plot(train_history)
        plt.show()

# %%
model.load_state_dict(torch.load('model.ckpt'))

# %%
train(1, 8e-4)

torch.save(model.state_dict(), 'model.ckpt')
# Out:
#   0%|          | 0/244 [00:00<?, ?it/s]
# Epoch [1/1], loss: 121961.8965

# %% [markdown]
# ## Things that did not work
#
# A U-net of convolutional and deconvolutional layers did not work. At best this achieved the identity function, which is of course useless. Using res-net seems to help, but again, this makes it much easier to achieve the identity function, which means it might not be a sign that it works after all.
#
# The first thing that was working was 3 convulutions from $3\times64\times64\rightarrow768\times8\times8$ and then a sub-pixel convolution $768\times8\times8\rightarrow3\times128\times128$.
#
# ![First working attemp model](resources/fwa.png)
#
# The result of a single subframe is shown here:
#
# ![First working attempt, subframe example](resources/fwa_subframe.png)
#
# When observing a single subframe, this looks very promising. You can notice that it looks a bit ragged, and there is also a small amount of color noise. When considering an entire frame, as shown below, the problems become more apparent.
#
# ![First working attempt, full frame original](resources/fwa_original.png)
# ![First working attempt, full frame upscaled](resources/fwa_upscaled.png)
#
# It is definitely not bad, but it is also not great. This model works really well in dealing with

# %%
# Switch model to evaluation mode to not keep track of gradients
model.eval()

# Get video
cap = cv2.VideoCapture("video/lowres_sample0.mkv")

video_resolution = (640, 480)

cap.set(cv2.CAP_PROP_POS_FRAMES, 10000)

# Number of subframes per axis per frame
n_subframes = (math.floor(video_resolution[0] / low_resolution[0]),
               math.floor(video_resolution[1] / low_resolution[1]))

target_resolution = (n_subframes[0] * high_resolution[0],
                     n_subframes[1] * high_resolution[1])

_, frame = cap.read()

# Resize to actual resolution
frame = cv2.resize(frame, video_resolution, interpolation=cv2.INTER_CUBIC)

cv2.imwrite('resources/original_frame.png', frame)

# Create a new empty image to insert the upscaled into
upscaled_image = np.zeros((target_resolution[1], target_resolution[0], 3), np.uint8)

normalize = Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

for x in range(n_subframes[0]):
    for y in range(n_subframes[1]):
        # Crop to a single subframe
        crop = frame[y*low_resolution[1]:(y+1)*low_resolution[1], 
                     x*low_resolution[0]:(x+1)*low_resolution[0]]
        
        # Upscale subframe to high_resolution
        norm = torch.unsqueeze(normalize(img_to_tensor(crop)), dim=0)
        up_tensor = denorm(model(norm).detach()[0])
        up_mat = up_tensor[[2,1,0], :, :].permute(1,2,0).numpy() * 256
        
        # Insert upscaled subframe into upscaled image
        upscaled_image[y*high_resolution[1]:(y+1)*high_resolution[1], 
                     x*high_resolution[0]:(x+1)*high_resolution[0]] = up_mat

cv2.imwrite('resources/upscaled_frame.png', upscaled_image)

# %%
kmodel = GreyUpscaleRecolor()
opt = torch.optim.Adam(kmodel.parameters(), lr=1e-3)
loss_fun = nn.MSELoss(reduction='sum')

for lr, hr in dataloader:
    grey_lr = torch.unsqueeze(torch.mean(lr, dim=1), dim=1)
    grey_hr = torch.unsqueeze(torch.mean(hr, dim=1), dim=1)
    
    output = kmodel(lr)
    print(torch.sum(torch.isnan(output)))
    
    loss = loss_fun(output, hr)
    print(torch.sum(torch.isnan(loss)))
    
    loss.backward()
    
    break
    opt.step()

# %%
a = torch.randn((1,2,2))
print(a)
b = torch.randn((3,2,2))
print(b)
p = a * b
print(p.shape, "\n", p)
